# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import statsmodels as sm
from statsmodels.tsa.stattools import adfuller

import sys
sys.path.insert(0, '..')

from funcs import test_stationarity, diff

# %%
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['text.color'] = 'k'
mpl.rcParams['figure.figsize'] = (9,5)
plt.style.use('ggplot')

# %% [markdown]
# # Load Data

# %%
time_series = pd.read_csv("../data/processed/time_series.csv", index_col="month")

# %%
time_series.head()

# %% [markdown]
# # Differentiation

# %% [markdown]
# ## First Difference

# %% [markdown]
# First log, then diff

# %%
#ts_log = pd.Series(np.log(time_series['active_users']))
ts_log = time_series['active_users']

# %%
ts_log[:5]

# %%
ts_first_diff = diff(ts_log,3)

# %%
ts_first_diff

# %%
ts_log.diff(3)

# %%
ts_first_diff.shape

# %%
plt.plot(ts_first_diff)
plt.show()

# %%
test_stationarity(ts_first_diff)

# %% [markdown]
# ## Second Difference

# %%
ts_sec_diff = diff(ts_first_diff,1)

# %%
ts_sec_diff[:5]

# %%
ts_first_diff.diff(3)

# %%
ts_sec_diff.shape

# %%
test_stationarity(ts_sec_diff)
